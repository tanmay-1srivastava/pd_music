# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Parkinson_Data_Collection/user_1_session_1_repetition_1_sensor_C52D26FB9648.csv')

# %%
print(df[0:8600])
# Out:
#                 timestamp     ax     ay     az     gx      gy     gz
# 0     1753364823293645200 -0.541  0.034 -0.822  0.282   0.191  0.244
# 1     1753364823301568900 -0.547  0.036 -0.829  0.107  -0.061  0.701
# 2     1753364823316119100 -0.546  0.033 -0.826  0.198   0.084  0.450
# 3     1753364823323524800 -0.546  0.034 -0.827  0.175   0.038  0.457
# 4     1753364823330974700 -0.547  0.033 -0.829  0.191  -0.046  0.419
# ...                   ...    ...    ...    ...    ...     ...    ...
# 8595  1753364908433212400 -0.542  0.059 -0.847 -0.709  -3.628  1.265
# 8596  1753364908448203000 -0.524  0.060 -0.845  0.053  -5.716  1.174
# 8597  1753364908463185800 -0.503  0.045 -0.843  0.983  -8.468  1.311
# 8598  1753364908464466000 -0.492  0.024 -0.829  1.014 -11.113  1.761
# 8599  1753364908471368600 -0.490  0.001 -0.827  0.640 -12.363  2.210
#
# [8600 rows x 7 columns]

# %%
plt.plot(df['timestamp'], df['ax'])
plt.xlim((1753364823293645200,  1753364908471368600))
# Out:
# (1.7533648232936453e+18, 1.7533649084713687e+18)
